# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import healpy as hp

# %%
NSIDE = 4096
print(
    "Approximate resolution at NSIDE {} is {:.2} deg".format(
        NSIDE, hp.nside2resol(NSIDE, arcmin=True) / 60
    )
)
# Out:
# Approximate resolution at NSIDE 4096 is 0.014 deg

# %%
NPIX = hp.nside2npix(NSIDE)
print(NPIX)
# Out:
# 201326592

# %%
recon_mirror_image = np.fromfile("./out10M_3d_viss_recon_tile/C1day10M.bin", dtype=np.float32)

hp.mollview(recon_mirror_image, nest=True, title="Mollview image healpix Viss Recon with NSIDE=4096")
hp.graticule()  # 添加经纬线
plt.show()

# %%
recon_mirror_image = np.fromfile("./out10M_3d_vissfast/C1day10M.bin", dtype=np.float32)

hp.mollview(recon_mirror_image, nest=True, title="Mollview image healpix Vissfast Recon with NSIDE=4096")
hp.graticule()  # 添加经纬线
plt.show()

# %%
recon_mirror_image = np.fromfile("./out10M_3d_halfnative/C1day10M.bin", dtype=np.float32)

hp.mollview(recon_mirror_image, nest=True, title="Mollview image healpix Half Native Recon with NSIDE=4096")
hp.graticule()  # 添加经纬线
plt.show()

# %%
recon_mirror_image = np.fromfile("./out10M_3d_system/C1day10M.bin", dtype=np.float32)

hp.mollview(recon_mirror_image, nest=True, title="Mollview image healpix System Recon with NSIDE=4096")
hp.graticule()  # 添加经纬线
plt.show()

# %%
recon_mirror_image = np.fromfile("./out10M_3d_shared_operator/C1day10M.bin", dtype=np.float32)

hp.mollview(recon_mirror_image, nest=True, title="Mollview image healpix Shared Operator Recon with NSIDE=4096")
hp.graticule()  # 添加经纬线
plt.show()

# %%
shared_operator_v2 = np.fromfile("./out10M_3d_shared_operator_v2/C1day10M.bin", dtype=np.float32)

hp.mollview(shared_operator_v2, nest=True, title="Mollview image healpix Shared Operator Recon V2 with NSIDE=4096")
hp.graticule()  # 添加经纬线
plt.show()

# %%
shared_operator_v2 = np.fromfile("./out10M_3d_stage2_balance/C1day10M.bin", dtype=np.float32)

hp.mollview(shared_operator_v2, nest=True, title="Mollview image healpix Stage2 balance with NSIDE=4096")
hp.graticule()  # 添加经纬线
plt.show()

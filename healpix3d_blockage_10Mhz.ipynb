# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import healpy as hp

# %%
NSIDE = 4096
print(
    "Approximate resolution at NSIDE {} is {:.2} deg".format(
        NSIDE, hp.nside2resol(NSIDE, arcmin=True) / 60
    )
)
# Out:
# Approximate resolution at NSIDE 4096 is 0.014 deg

# %%
NPIX = hp.nside2npix(NSIDE)
print(NPIX)
# Out:
# 201326592

# %%
recon_mirror_image = np.fromfile("./out10M_3d_viss_recon_tile/C1day10M.bin", dtype=np.float32)

hp.mollview(recon_mirror_image, nest=True, title="Mollview image healpix Recon Mirror with NSIDE=4096")
hp.graticule()  # 添加经纬线
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import healpy as hp

# %%
NSIDE = 4096
print(
    "Approximate resolution at NSIDE {} is {:.2} deg".format(
        NSIDE, hp.nside2resol(NSIDE, arcmin=True) / 60
    )
)
# Out:
# Approximate resolution at NSIDE 4096 is 0.014 deg

# %%
NPIX = hp.nside2npix(NSIDE)
print(NPIX)
# Out:
# 201326592

# %%
ori = np.loadtxt("./earth_10Mhz/B_10M_original.txt")

# %%
hp.mollview(ori, nest=True, title="Mollview image B with NSIDE=4096")
hp.graticule()  # 添加经纬线
plt.show()

# %%
total_data = np.loadtxt("./3dblockage10M/C1day1M.txt")
    
hp.mollview(total_data, nest=True, title="Mollview image healpix Blockage with NSIDE=4096")
hp.graticule()  # 添加经纬线
plt.show()

# %%
total_data = np.loadtxt("./3dblockage/C1day1M.txt")

# 读取并累加450个文件
for i in range(2, 451):
    file_path = f"./3dblockage/C{i}day1M.txt"
    data = np.loadtxt(file_path)
    
    # 将nan值转换为0
    data = np.nan_to_num(data)
    
    # 累加数据
    total_data += data
    
hp.mollview(total_data, nest=True, title="Mollview image healpix Blockage with NSIDE=512")
hp.graticule()  # 添加经纬线
plt.show()
